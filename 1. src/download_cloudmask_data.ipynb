# %% [markdown]
# # Import packages

# %%
# Packages
from IPython.core.display import HTML
import pandas as pd
import numpy as np
import xarray as xr
from datetime import datetime
import requests
import shutil
import time
import eumdac
import os
# Out:
# /Users/eugenerotherham/Desktop/Environments/Atheras_Analytics/lib/python3.9/site-packages/ecmwflibs/__init__.py:83: UserWarning: dlopen(/Users/eugenerotherham/Desktop/Environments/Atheras_Analytics/lib/python3.9/site-packages/ecmwflibs/_ecmwflibs.cpython-39-darwin.so, 2): Symbol not found: __ZNKSt3__115basic_stringbufIcNS_11char_traitsIcEENS_9allocatorIcEEE3strEv
#   Referenced from: /Users/eugenerotherham/Desktop/Environments/Atheras_Analytics/lib/python3.9/site-packages/ecmwflibs/.dylibs/libproj.25.9.1.0.dylib (which was built for Mac OS X 12.0)
#   Expected in: /usr/lib/libc++.1.dylib
#
#   warnings.warn(str(e))

# %%
# Constants
consumer_key = '8fmYIf3P4ugcQJGZuNAF13i_fzwa'
consumer_secret =  'TM7zBHbXrL7ukrQ7ltGM2NplCcAa'
MAX_RETRIES = 10
raw_grib_destination_folder = '/Users/eugenerotherham/Documents/AtherasAnalytics/clouds-outage-prediction-main/eumetsat_lab/grib_staging_folder/'
results_destination_folder = '/Users/eugenerotherham/Documents/AtherasAnalytics/clouds-outage-prediction-main/eumetsat_lab/results/'

# %% [markdown]
# # Functions

# %%
def get_eumetsat_api_token():
    credentials = (consumer_key, consumer_secret)
    token = eumdac.AccessToken(credentials)
    try:
        print(f"This token '{token}' expires {token.expiration}")
    except requests.exceptions.HTTPError as exc:
        print(f"Error when tryng the request to the server: '{exc}'")
    return token

# %%
def get_collection(token, collection_id):
    datastore = eumdac.DataStore(token)
    selected_collection = datastore.get_collection(collection_id)
    
    try:
        print(selected_collection.search_options)
    except eumdac.datastore.DataStoreError as error:
        print(f"Error related to the data store: '{error.msg}'")
    except eumdac.collection.CollectionError as error:
        print(f"Error related to the collection: '{error.msg}'")
    except requests.exceptions.RequestException as error:
        print(f"Unexpected error: {error}")
    return selected_collection, datastore

# %%
def get_product_list(selected_collection, start_date, end_date):
    products = selected_collection.search(
            dtstart=start_date, 
            dtend=end_date)
    try:
        print(f'Found Datasets: {len(products)} datasets for the given time range.')   
    except eumdac.collection.CollectionError as error:
        print(f"Error related to the collection: '{error.msg}'")
    except requests.exceptions.RequestException as error:
        print(f"Unexpected error: {error}")

    product_list = []

    for product in products:
        retries = 0
        while retries < MAX_RETRIES:
            try:
                product_list.append(str(product))
                break
            except eumdac.product.ProductError as error:
                print(f"Error related to the product: '{error.msg}'")
            except requests.exceptions.RequestException as error:
                print(f"Unexpected error: {error}")
            
    return product_list

# %%
def get_station_bbox():

    # List all stations of interest just inpout code and their coordinates
    locations_data_df = {
            'station_code': ['matm', 'grsm'],
            'lon/lat': [(16.7046, 40.6486), (6.9216, 43.7546)]
        }

    # Area to average cloud coverage over (in degrees)
    scan_radius = 0.1

    station_bbox_list = []

    for index, row in pd.DataFrame(locations_data_df).iterrows():
        station_code = row['station_code']
        coord = row['lon/lat']
        
        lat_min = coord[1] - scan_radius
        lat_max = coord[1] + scan_radius
        lon_min = coord[0] - scan_radius
        lon_max = coord[0] + scan_radius
        bbox = [lat_min, lat_max, lon_min, lon_max]
        
        station_bbox_list.append({
            'station_code': station_code,
            'coord': coord,
            'bbox': bbox
        })

    station_bbox_df = pd.DataFrame(station_bbox_list)

    return station_bbox_df

# %%
def download_products(product_id, collection_id, datastore):
    
    selected_product = datastore.get_product(product_id=product_id, collection_id=collection_id)

    retries = 0
    grib_file_name = product_id + '.grb'
    
    while retries < MAX_RETRIES:
        try:
            with selected_product.open(entry=grib_file_name) as fsrc, \
                    open(raw_grib_destination_folder + grib_file_name, mode='wb') as fdst:
                shutil.copyfileobj(fsrc, fdst)
                break
        except eumdac.product.ProductError as error:
            if error.extra_info['status'] >= 500:
                wait = retries * 10
                time.sleep(wait)
                print(f"Attempt {retries}/{MAX_RETRIES}: {error}")
                retries += 1
            else:
                print(
                    f"Error related to the product '{selected_product}' while trying to download it: '{error.msg}'")
        except requests.exceptions.ConnectionError as error:
            wait = retries * 10
            time.sleep(wait)
            print(f"Attempt {retries}/{MAX_RETRIES}: {error}")
            retries += 1
        except requests.exceptions.RequestException as error:
            if error.extra_info['status'] >= 500:
                wait = retries * 10
                time.sleep(wait)
                print(f"Attempt {retries}/{MAX_RETRIES}: {error}")
                retries += 1
            else:
                print(f"Unexpected error: {error}")
    
    return grib_file_name

# %%
def get_date(grib_file_name):
    
    # Find the position of the 5th dash and the first full stop
    fifth_dash_pos = -1
    for _ in range(5):
        fifth_dash_pos = grib_file_name.find('-', fifth_dash_pos + 1)
    first_dot_pos = grib_file_name.index('.')
    
    # Extract the datetime part
    datetime_part = grib_file_name[fifth_dash_pos + 1 : first_dot_pos]
    #product_date = datetime.strptime(datetime_part, '%Y%m%d%H%M%S')

    return datetime_part

# %% [markdown]
# # Main

# %%
import datetime

current_date = datetime.datetime(2023, 6, 1)

while current_date < datetime.datetime(2023, 8, 1):
    formatted_date = current_date.strftime('%Y-%m-%d')
    start_date = formatted_date
    end_date = (current_date + datetime.timedelta(days=31)).replace(day=1) - datetime.timedelta(days=1)
    print(f'start date: {start_date}')
    print(f'end date: {end_date}')

    # go

    current_date = current_date.replace(day=1) + datetime.timedelta(days=31)  # Move to the first day of the next month
# Out:
# start date: 2023-06-01
# end date: 2023-06-30 00:00:00
# start date: 2023-07-02
# end date: 2023-07-31 00:00:00

# %%
# Initial parameters
import datetime

collection_id = 'EO:EUM:DAT:MSG:CLM'
start_date = datetime.datetime(2023, 6, 1, 0, 0)
end_date = datetime.datetime(2023, 8, 1, 0, 0)

token = get_eumetsat_api_token()

selected_collection, datastore = get_collection(token, collection_id)

product_list = get_product_list(selected_collection, start_date, end_date)

station_bbox_df = get_station_bbox()
# Out:
# This token 'ff3ed47f-dabc-39f0-87c1-d479eb491a54' expires 2023-08-24 23:31:17.727020
# {'bbox': {'title': 'Inventory which has a spatial extent overlapping this bounding box', 'options': []}, 'geo': {'title': 'Inventory which has a spatial extent overlapping this Well Known Text geometry', 'options': []}, 'title': {'title': 'Can be used to define a wildcard search on the product title (product identifier), use set notation as OR and space as AND operator between multiple search terms', 'options': [None]}, 'sat': {'title': 'Mission / Satellite', 'options': ['MSG2', 'MSG3', 'MSG4', 'MSG1']}, 'type': {'title': 'Product Type', 'options': ['MSGCLMK']}, 'dtstart': {'title': 'Temporal Start', 'options': []}, 'dtend': {'title': 'Temporal End', 'options': []}, 'publication': {'title': 'publication date', 'options': []}, 'sort': {'title': 'SRU sort keys, see OpenSearch Extension for EO for details', 'options': ['publicationDate', 'start,time']}, 'set': {'title': 'element set to return for each hit, default is full', 'options': ['full', 'brief']}}
# Found Datasets: 5857 datasets for the given time range.

# %%
# Create empty weather DataFrames for each station using dictionary comprehension
station_weather_dataframes = {row['station_code']: pd.DataFrame(columns=['time', 'cloud_cov']) for index, row in station_bbox_df.iterrows()}

total_products = len(product_list)
for i, product_id in enumerate(product_list, 1):  # Start index from 1 to match human counting

    print(f"Parsing GRIB: {i}/{total_products}")

    try:
        # Download dataset
        grib_file_name = download_products(product_id, collection_id, datastore) 
        product_date = get_date(grib_file_name)

        # Open dataset
        ds=xr.open_dataset(raw_grib_destination_folder+grib_file_name,engine='cfgrib',backend_kwargs={'indexpath': ''})

        # Prepare and format data for plotting
        data_array = ds['p260537']
        latitude = data_array['latitude']
        longitude = data_array['longitude']
        longitude = (longitude + 180) % 360 - 180
        longitude = longitude[::-1]
        latitude = latitude[::-1]
        # Convert to pandas series
        data_series = pd.Series(data_array, name='cloud_mask')
        latitude_series = pd.Series(latitude, name='latitude')
        longitude_series = pd.Series(longitude, name='longitude')
        # Convert to pandas dataframe
        raw_df = pd.concat([latitude_series, longitude_series, data_series], axis=1)
        
        # In current dataset extract cloud cov from each station    and add to station datframe save to txt file
        for index, row in station_bbox_df.iterrows():      
            bbox = row['bbox']
            station_code = row['station_code']
            filtered_df = raw_df[(raw_df['latitude'] >= bbox[0]) & (raw_df['latitude'] <= bbox[1]) & (raw_df['longitude'] >= bbox[2]) & (raw_df['longitude'] <= bbox[3])]
            
            cloudy_sum = (filtered_df['cloud_mask'] == 2).sum()
            total = len(filtered_df['cloud_mask'])
            station_cloud_cov = (cloudy_sum / total)*100

            station_cloud_cov_to_be_added = {'time': product_date, 'cloud_cov': station_cloud_cov}
            station_weather_dataframes[station_code] = pd.concat([station_weather_dataframes[station_code], pd.DataFrame([station_cloud_cov_to_be_added])], ignore_index=True)
        
        # Delete the GRIB file from the file system if it exists
        ds.close()
        file_path = os.path.join(raw_grib_destination_folder, grib_file_name)
        if os.path.exists(file_path):
            os.remove(file_path)
    except BaseException as e:
        print(f"An error occurred: {type(e).__name__} - {e}")
        continue
    
for index, row in station_bbox_df.iterrows():   
    station_code = row['station_code']
    station_weather_dataframes[station_code].to_csv(f"{results_destination_folder}{station_code}_eumetsat_{start_date}_{end_date}_df", sep='\t')
# Out:
# Parsing GRIB: 1/5857
# Parsing GRIB: 2/5857
# Parsing GRIB: 3/5857
# Parsing GRIB: 4/5857
# Parsing GRIB: 5/5857
# Parsing GRIB: 6/5857
# Parsing GRIB: 7/5857
# Parsing GRIB: 8/5857
# Parsing GRIB: 9/5857
# Parsing GRIB: 10/5857
# Parsing GRIB: 11/5857
# Parsing GRIB: 12/5857
# Parsing GRIB: 13/5857
# Parsing GRIB: 14/5857
# Parsing GRIB: 15/5857
# Parsing GRIB: 16/5857
# Parsing GRIB: 17/5857
# Parsing GRIB: 18/5857
# Parsing GRIB: 19/5857
# Parsing GRIB: 20/5857
# Parsing GRIB: 21/5857
# Parsing GRIB: 22/5857
# Parsing GRIB: 23/5857
# Parsing GRIB: 24/5857
# Parsing GRIB: 25/5857
# Parsing GRIB: 26/5857
# Parsing GRIB: 27/5857
# Parsing GRIB: 28/5857
# Parsing GRIB: 29/5857
# Parsing GRIB: 30/5857
# Parsing GRIB: 31/5857
# Parsing GRIB: 32/5857
# Parsing GRIB: 33/5857
# Parsing GRIB: 34/5857
# Parsing GRIB: 35/5857
# Parsing GRIB: 36/5857
# Parsing GRIB: 37/5857
# Parsing GRIB: 38/5857
# Parsing GRIB: 39/5857
# Parsing GRIB: 40/5857
# Parsing GRIB: 41/5857
# Parsing GRIB: 42/5857
# Parsing GRIB: 43/5857
# Parsing GRIB: 44/5857
# Parsing GRIB: 45/5857
# Parsing GRIB: 46/5857
# Parsing GRIB: 47/5857
# Parsing GRIB: 48/5857
# Parsing GRIB: 49/5857
# Parsing GRIB: 50/5857
# Parsing GRIB: 51/5857
# Parsing GRIB: 52/5857
# Parsing GRIB: 53/5857
# Parsing GRIB: 54/5857
# Parsing GRIB: 55/5857
# Parsing GRIB: 56/5857
# Parsing GRIB: 57/5857
# Parsing GRIB: 58/5857
# Parsing GRIB: 59/5857
# Parsing GRIB: 60/5857
# Parsing GRIB: 61/5857
# Parsing GRIB: 62/5857
# Parsing GRIB: 63/5857
# Parsing GRIB: 64/5857
# Parsing GRIB: 65/5857
# Parsing GRIB: 66/5857
# Parsing GRIB: 67/5857
# Parsing GRIB: 68/5857
# Parsing GRIB: 69/5857
# Parsing GRIB: 70/5857
# Parsing GRIB: 71/5857
# Parsing GRIB: 72/5857
# Parsing GRIB: 73/5857
# Parsing GRIB: 74/5857
# Parsing GRIB: 75/5857
# Parsing GRIB: 76/5857
# Parsing GRIB: 77/5857
# Parsing GRIB: 78/5857
# Parsing GRIB: 79/5857
# Parsing GRIB: 80/5857
# Parsing GRIB: 81/5857
# Parsing GRIB: 82/5857
# Parsing GRIB: 83/5857
# Parsing GRIB: 84/5857
# Parsing GRIB: 85/5857
# Parsing GRIB: 86/5857
# Parsing GRIB: 87/5857
# Parsing GRIB: 88/5857
# Parsing GRIB: 89/5857
# Parsing GRIB: 90/5857
# Parsing GRIB: 91/5857
# Parsing GRIB: 92/5857
# Parsing GRIB: 93/5857
# Parsing GRIB: 94/5857
# Parsing GRIB: 95/5857
# Parsing GRIB: 96/5857
# Parsing GRIB: 97/5857
# Parsing GRIB: 98/5857
# Parsing GRIB: 99/5857
# Parsing GRIB: 100/5857
# Parsing GRIB: 101/5857
# Parsing GRIB: 102/5857
# Parsing GRIB: 103/5857
# Parsing GRIB: 104/5857
# Parsing GRIB: 105/5857
# Parsing GRIB: 106/5857
# Parsing GRIB: 107/5857
# Parsing GRIB: 108/5857
# Parsing GRIB: 109/5857
# Parsing GRIB: 110/5857
# Parsing GRIB: 111/5857
# Parsing GRIB: 112/5857
# Parsing GRIB: 113/5857
# Parsing GRIB: 114/5857
# Parsing GRIB: 115/5857
# Parsing GRIB: 116/5857
# Parsing GRIB: 117/5857
# Parsing GRIB: 118/5857
# Parsing GRIB: 119/5857
# Parsing GRIB: 120/5857
# Parsing GRIB: 121/5857
# Parsing GRIB: 122/5857
# Parsing GRIB: 123/5857
# Parsing GRIB: 124/5857
# Parsing GRIB: 125/5857
# Parsing GRIB: 126/5857
# Parsing GRIB: 127/5857
# Parsing GRIB: 128/5857
# Parsing GRIB: 129/5857
# Parsing GRIB: 130/5857
# Parsing GRIB: 131/5857
# Parsing GRIB: 132/5857
# Parsing GRIB: 133/5857
# Parsing GRIB: 134/5857
# Parsing GRIB: 135/5857
# Parsing GRIB: 136/5857
# Parsing GRIB: 137/5857
# Parsing GRIB: 138/5857
# Parsing GRIB: 139/5857
# Parsing GRIB: 140/5857
# Parsing GRIB: 141/5857
# Parsing GRIB: 142/5857
# Parsing GRIB: 143/5857
# Parsing GRIB: 144/5857
# Parsing GRIB: 145/5857
# Parsing GRIB: 146/5857
# Parsing GRIB: 147/5857
# Parsing GRIB: 148/5857
# Parsing GRIB: 149/5857
# Parsing GRIB: 150/5857
# Parsing GRIB: 151/5857
# Parsing GRIB: 152/5857
# Parsing GRIB: 153/5857
# Parsing GRIB: 154/5857
# Parsing GRIB: 155/5857
# Parsing GRIB: 156/5857
# Parsing GRIB: 157/5857
# Parsing GRIB: 158/5857
# Parsing GRIB: 159/5857
# Parsing GRIB: 160/5857
# Parsing GRIB: 161/5857
# Parsing GRIB: 162/5857
# Parsing GRIB: 163/5857
# Parsing GRIB: 164/5857
# Parsing GRIB: 165/5857
# Parsing GRIB: 166/5857
# Parsing GRIB: 167/5857
# Parsing GRIB: 168/5857
# Parsing GRIB: 169/5857
# Parsing GRIB: 170/5857
# Parsing GRIB: 171/5857
# Parsing GRIB: 172/5857
# Parsing GRIB: 173/5857
# Parsing GRIB: 174/5857
# Parsing GRIB: 175/5857
# Parsing GRIB: 176/5857
# Parsing GRIB: 177/5857
# Parsing GRIB: 178/5857
# Parsing GRIB: 179/5857
# Parsing GRIB: 180/5857
# Parsing GRIB: 181/5857
# Parsing GRIB: 182/5857
# Parsing GRIB: 183/5857
# Parsing GRIB: 184/5857
# Parsing GRIB: 185/5857
# Parsing GRIB: 186/5857
# Parsing GRIB: 187/5857
# Parsing GRIB: 188/5857
# Parsing GRIB: 189/5857
# Parsing GRIB: 190/5857
# Parsing GRIB: 191/5857
# Parsing GRIB: 192/5857
# Parsing GRIB: 193/5857
# Parsing GRIB: 194/5857
# Parsing GRIB: 195/5857
# Parsing GRIB: 196/5857
# Parsing GRIB: 197/5857
# Parsing GRIB: 198/5857
# Parsing GRIB: 199/5857
# Parsing GRIB: 200/5857
# Parsing GRIB: 201/5857
# Parsing GRIB: 202/5857
# Parsing GRIB: 203/5857
# Parsing GRIB: 204/5857
# Parsing GRIB: 205/5857
# Parsing GRIB: 206/5857
# Parsing GRIB: 207/5857
# Parsing GRIB: 208/5857
# Parsing GRIB: 209/5857
# Parsing GRIB: 210/5857
# Parsing GRIB: 211/5857
# Parsing GRIB: 212/5857
# Parsing GRIB: 213/5857
# Parsing GRIB: 214/5857
# Parsing GRIB: 215/5857
# Parsing GRIB: 216/5857
# Parsing GRIB: 217/5857
# Parsing GRIB: 218/5857
# Parsing GRIB: 219/5857
# Parsing GRIB: 220/5857
# Parsing GRIB: 221/5857
# Parsing GRIB: 222/5857
# Parsing GRIB: 223/5857
# Parsing GRIB: 224/5857
# Parsing GRIB: 225/5857
# Parsing GRIB: 226/5857
# Parsing GRIB: 227/5857
# Parsing GRIB: 228/5857
# Parsing GRIB: 229/5857
# Parsing GRIB: 230/5857
# Parsing GRIB: 231/5857
# Parsing GRIB: 232/5857
# Parsing GRIB: 233/5857
# Parsing GRIB: 234/5857
# Parsing GRIB: 235/5857
# Parsing GRIB: 236/5857
# Parsing GRIB: 237/5857
# Parsing GRIB: 238/5857
# Parsing GRIB: 239/5857
# Parsing GRIB: 240/5857
# Parsing GRIB: 241/5857
# Parsing GRIB: 242/5857
# Parsing GRIB: 243/5857
# Parsing GRIB: 244/5857
# Parsing GRIB: 245/5857
# Parsing GRIB: 246/5857
# Parsing GRIB: 247/5857
# Parsing GRIB: 248/5857
# Parsing GRIB: 249/5857
# Parsing GRIB: 250/5857
# Parsing GRIB: 251/5857
# Parsing GRIB: 252/5857
# Parsing GRIB: 253/5857
# Parsing GRIB: 254/5857
# Parsing GRIB: 255/5857
# Parsing GRIB: 256/5857
# Parsing GRIB: 257/5857
# Parsing GRIB: 258/5857
# Parsing GRIB: 259/5857
# Parsing GRIB: 260/5857
# Parsing GRIB: 261/5857
# Parsing GRIB: 262/5857
# Parsing GRIB: 263/5857
# Parsing GRIB: 264/5857
# Parsing GRIB: 265/5857
# Parsing GRIB: 266/5857
# Parsing GRIB: 267/5857
# Parsing GRIB: 268/5857
# Parsing GRIB: 269/5857
# Parsing GRIB: 270/5857
# Parsing GRIB: 271/5857
# Parsing GRIB: 272/5857
# Parsing GRIB: 273/5857
# Parsing GRIB: 274/5857
# Parsing GRIB: 275/5857
# Parsing GRIB: 276/5857
# Parsing GRIB: 277/5857
# Parsing GRIB: 278/5857
# Parsing GRIB: 279/5857
# Parsing GRIB: 280/5857
# Parsing GRIB: 281/5857
# Parsing GRIB: 282/5857
# Parsing GRIB: 283/5857
# Parsing GRIB: 284/5857
# Parsing GRIB: 285/5857
# Parsing GRIB: 286/5857
# Parsing GRIB: 287/5857
# Parsing GRIB: 288/5857
# Parsing GRIB: 289/5857
# Parsing GRIB: 290/5857
# Parsing GRIB: 291/5857
# Parsing GRIB: 292/5857
# Parsing GRIB: 293/5857
# Parsing GRIB: 294/5857
# Parsing GRIB: 295/5857
# Parsing GRIB: 296/5857
# Parsing GRIB: 297/5857
# Parsing GRIB: 298/5857
# Parsing GRIB: 299/5857
# Parsing GRIB: 300/5857
# Parsing GRIB: 301/5857
# Parsing GRIB: 302/5857
# Parsing GRIB: 303/5857
# Parsing GRIB: 304/5857
# Parsing GRIB: 305/5857
# Parsing GRIB: 306/5857
# Parsing GRIB: 307/5857
# Parsing GRIB: 308/5857
# Parsing GRIB: 309/5857
# Parsing GRIB: 310/5857
# Parsing GRIB: 311/5857
# Parsing GRIB: 312/5857
# Parsing GRIB: 313/5857
# Parsing GRIB: 314/5857
# Parsing GRIB: 315/5857
# Parsing GRIB: 316/5857
# Parsing GRIB: 317/5857
# Parsing GRIB: 318/5857
# Parsing GRIB: 319/5857
# Parsing GRIB: 320/5857
# Parsing GRIB: 321/5857
# Parsing GRIB: 322/5857
# Parsing GRIB: 323/5857
# Parsing GRIB: 324/5857
# Parsing GRIB: 325/5857
# Parsing GRIB: 326/5857
# Parsing GRIB: 327/5857
# Parsing GRIB: 328/5857
# Parsing GRIB: 329/5857
# Parsing GRIB: 330/5857
# Parsing GRIB: 331/5857
# Parsing GRIB: 332/5857
# Parsing GRIB: 333/5857
# Parsing GRIB: 334/5857
# Parsing GRIB: 335/5857
# Parsing GRIB: 336/5857
# Parsing GRIB: 337/5857
# Parsing GRIB: 338/5857
# Parsing GRIB: 339/5857
# Parsing GRIB: 340/5857
# Parsing GRIB: 341/5857
# Parsing GRIB: 342/5857
# Parsing GRIB: 343/5857
# Parsing GRIB: 344/5857
# Parsing GRIB: 345/5857
# Parsing GRIB: 346/5857
# Parsing GRIB: 347/5857
# Parsing GRIB: 348/5857
# Parsing GRIB: 349/5857
# Parsing GRIB: 350/5857
# Parsing GRIB: 351/5857
# Parsing GRIB: 352/5857
# Parsing GRIB: 353/5857
# Parsing GRIB: 354/5857
# Parsing GRIB: 355/5857
# Parsing GRIB: 356/5857
# Parsing GRIB: 357/5857
# Parsing GRIB: 358/5857
# Parsing GRIB: 359/5857
# Parsing GRIB: 360/5857
# Parsing GRIB: 361/5857
# Parsing GRIB: 362/5857
# Parsing GRIB: 363/5857
# Parsing GRIB: 364/5857
# Parsing GRIB: 365/5857
# Parsing GRIB: 366/5857
# Parsing GRIB: 367/5857
# Parsing GRIB: 368/5857
# Parsing GRIB: 369/5857
# Parsing GRIB: 370/5857
# Parsing GRIB: 371/5857
# Parsing GRIB: 372/5857
# Parsing GRIB: 373/5857
# Parsing GRIB: 374/5857
# Parsing GRIB: 375/5857
# Parsing GRIB: 376/5857
# Parsing GRIB: 377/5857
# Parsing GRIB: 378/5857
# Parsing GRIB: 379/5857
# Parsing GRIB: 380/5857
# Parsing GRIB: 381/5857
# Parsing GRIB: 382/5857
# Parsing GRIB: 383/5857
# Parsing GRIB: 384/5857
# Parsing GRIB: 385/5857
# Parsing GRIB: 386/5857
# Parsing GRIB: 387/5857
# Parsing GRIB: 388/5857
# Parsing GRIB: 389/5857
# Parsing GRIB: 390/5857
# Parsing GRIB: 391/5857
# Parsing GRIB: 392/5857
# Parsing GRIB: 393/5857
# Parsing GRIB: 394/5857
# Parsing GRIB: 395/5857
# Parsing GRIB: 396/5857
# Parsing GRIB: 397/5857
# Parsing GRIB: 398/5857
# Parsing GRIB: 399/5857
# Parsing GRIB: 400/5857
# Parsing GRIB: 401/5857
# Parsing GRIB: 402/5857
# Parsing GRIB: 403/5857
# Parsing GRIB: 404/5857
# Parsing GRIB: 405/5857
# Parsing GRIB: 406/5857
# Parsing GRIB: 407/5857
# Parsing GRIB: 408/5857
# Parsing GRIB: 409/5857
# Parsing GRIB: 410/5857
# Parsing GRIB: 411/5857
# Parsing GRIB: 412/5857
# Parsing GRIB: 413/5857
# Parsing GRIB: 414/5857
# Parsing GRIB: 415/5857
# Parsing GRIB: 416/5857
# Parsing GRIB: 417/5857
# Parsing GRIB: 418/5857
# Parsing GRIB: 419/5857
# Parsing GRIB: 420/5857
# Parsing GRIB: 421/5857
# Parsing GRIB: 422/5857
# Parsing GRIB: 423/5857
# Parsing GRIB: 424/5857
# Parsing GRIB: 425/5857
# Parsing GRIB: 426/5857
# Parsing GRIB: 427/5857
# Parsing GRIB: 428/5857
# Parsing GRIB: 429/5857
# Parsing GRIB: 430/5857
# Parsing GRIB: 431/5857
# Parsing GRIB: 432/5857
# Parsing GRIB: 433/5857
# Parsing GRIB: 434/5857
# Parsing GRIB: 435/5857
# Parsing GRIB: 436/5857
# Parsing GRIB: 437/5857
# Parsing GRIB: 438/5857
# Parsing GRIB: 439/5857
# Parsing GRIB: 440/5857
# Parsing GRIB: 441/5857
# Parsing GRIB: 442/5857
# Parsing GRIB: 443/5857
# Parsing GRIB: 444/5857
# Parsing GRIB: 445/5857
# Parsing GRIB: 446/5857
# Parsing GRIB: 447/5857
# Parsing GRIB: 448/5857
# Parsing GRIB: 449/5857
# Parsing GRIB: 450/5857
# Parsing GRIB: 451/5857
# Parsing GRIB: 452/5857
# Parsing GRIB: 453/5857
# Parsing GRIB: 454/5857
# Parsing GRIB: 455/5857
# Parsing GRIB: 456/5857
# Parsing GRIB: 457/5857
# Parsing GRIB: 458/5857
# Parsing GRIB: 459/5857
# Parsing GRIB: 460/5857
# Parsing GRIB: 461/5857
# Parsing GRIB: 462/5857
# Parsing GRIB: 463/5857
# Parsing GRIB: 464/5857
# Parsing GRIB: 465/5857
# Parsing GRIB: 466/5857
# Parsing GRIB: 467/5857
# Parsing GRIB: 468/5857
# Parsing GRIB: 469/5857
# Parsing GRIB: 470/5857
# Parsing GRIB: 471/5857
# Parsing GRIB: 472/5857
# Parsing GRIB: 473/5857
# Parsing GRIB: 474/5857
# Parsing GRIB: 475/5857
# Parsing GRIB: 476/5857
# Parsing GRIB: 477/5857
# Parsing GRIB: 478/5857
# Parsing GRIB: 479/5857
# Parsing GRIB: 480/5857
# Parsing GRIB: 481/5857
# Parsing GRIB: 482/5857
# Parsing GRIB: 483/5857
# Parsing GRIB: 484/5857
# Parsing GRIB: 485/5857
# Parsing GRIB: 486/5857
# Parsing GRIB: 487/5857
# Parsing GRIB: 488/5857
# Parsing GRIB: 489/5857
# Parsing GRIB: 490/5857
# Parsing GRIB: 491/5857
# Parsing GRIB: 492/5857
# Parsing GRIB: 493/5857
# Parsing GRIB: 494/5857
# Parsing GRIB: 495/5857
# Parsing GRIB: 496/5857
# Parsing GRIB: 497/5857
# Parsing GRIB: 498/5857
# Parsing GRIB: 499/5857
# Parsing GRIB: 500/5857
# Parsing GRIB: 501/5857
# Parsing GRIB: 502/5857
# Parsing GRIB: 503/5857
# Parsing GRIB: 504/5857
# Parsing GRIB: 505/5857
# Parsing GRIB: 506/5857
# Parsing GRIB: 507/5857
# Parsing GRIB: 508/5857
# Parsing GRIB: 509/5857
# Parsing GRIB: 510/5857
# Parsing GRIB: 511/5857
# Parsing GRIB: 512/5857
# Parsing GRIB: 513/5857
# Parsing GRIB: 514/5857
# Parsing GRIB: 515/5857
# Parsing GRIB: 516/5857
# Parsing GRIB: 517/5857
# Parsing GRIB: 518/5857
# Parsing GRIB: 519/5857
# Parsing GRIB: 520/5857
# Parsing GRIB: 521/5857
# Parsing GRIB: 522/5857
# Parsing GRIB: 523/5857
# Parsing GRIB: 524/5857
# Parsing GRIB: 525/5857
# Parsing GRIB: 526/5857
# Parsing GRIB: 527/5857
# Parsing GRIB: 528/5857
# Parsing GRIB: 529/5857
# Parsing GRIB: 530/5857
# Parsing GRIB: 531/5857
# Parsing GRIB: 532/5857
# Parsing GRIB: 533/5857
# Parsing GRIB: 534/5857
# Parsing GRIB: 535/5857
# Parsing GRIB: 536/5857
# Parsing GRIB: 537/5857
# Parsing GRIB: 538/5857
# Parsing GRIB: 539/5857
# Parsing GRIB: 540/5857
# Parsing GRIB: 541/5857
# Parsing GRIB: 542/5857
# Parsing GRIB: 543/5857
# Parsing GRIB: 544/5857
# Parsing GRIB: 545/5857
# Parsing GRIB: 546/5857
# Parsing GRIB: 547/5857
# Parsing GRIB: 548/5857
# Parsing GRIB: 549/5857
# Parsing GRIB: 550/5857
# Parsing GRIB: 551/5857
# Parsing GRIB: 552/5857
# Parsing GRIB: 553/5857
# Parsing GRIB: 554/5857
# Parsing GRIB: 555/5857
# Parsing GRIB: 556/5857
# Parsing GRIB: 557/5857
# Parsing GRIB: 558/5857
# Parsing GRIB: 559/5857
# Parsing GRIB: 560/5857
# Parsing GRIB: 561/5857
# Parsing GRIB: 562/5857
# Parsing GRIB: 563/5857
# Parsing GRIB: 564/5857
# Parsing GRIB: 565/5857
# Parsing GRIB: 566/5857
# Parsing GRIB: 567/5857
# Parsing GRIB: 568/5857
# Parsing GRIB: 569/5857
# Parsing GRIB: 570/5857
# Parsing GRIB: 571/5857
# Parsing GRIB: 572/5857
# Parsing GRIB: 573/5857
# Parsing GRIB: 574/5857
# Parsing GRIB: 575/5857
# Parsing GRIB: 576/5857
# Parsing GRIB: 577/5857
# Parsing GRIB: 578/5857
# Parsing GRIB: 579/5857
# Parsing GRIB: 580/5857
# Parsing GRIB: 581/5857
# Parsing GRIB: 582/5857
# Parsing GRIB: 583/5857
# Parsing GRIB: 584/5857
# Parsing GRIB: 585/5857
# Parsing GRIB: 586/5857
# Parsing GRIB: 587/5857
# Parsing GRIB: 588/5857
# Parsing GRIB: 589/5857
# Parsing GRIB: 590/5857
# Parsing GRIB: 591/5857
# Parsing GRIB: 592/5857
# Parsing GRIB: 593/5857
# Parsing GRIB: 594/5857
# Parsing GRIB: 595/5857
# Parsing GRIB: 596/5857
# Parsing GRIB: 597/5857
# Parsing GRIB: 598/5857
# Parsing GRIB: 599/5857
# Parsing GRIB: 600/5857
# Parsing GRIB: 601/5857
# Parsing GRIB: 602/5857
# Parsing GRIB: 603/5857
# Parsing GRIB: 604/5857
# Parsing GRIB: 605/5857
# Parsing GRIB: 606/5857
# Parsing GRIB: 607/5857
# Parsing GRIB: 608/5857
# Parsing GRIB: 609/5857
# Parsing GRIB: 610/5857
# Parsing GRIB: 611/5857
# Parsing GRIB: 612/5857
# Parsing GRIB: 613/5857
# Parsing GRIB: 614/5857
# Parsing GRIB: 615/5857
# Parsing GRIB: 616/5857
# Parsing GRIB: 617/5857
# Parsing GRIB: 618/5857
# Parsing GRIB: 619/5857
# Parsing GRIB: 620/5857
# Parsing GRIB: 621/5857
# Parsing GRIB: 622/5857
# Parsing GRIB: 623/5857
# Parsing GRIB: 624/5857
# Parsing GRIB: 625/5857
# Parsing GRIB: 626/5857
# Parsing GRIB: 627/5857
# Parsing GRIB: 628/5857
# Parsing GRIB: 629/5857
# Parsing GRIB: 630/5857
# Parsing GRIB: 631/5857
# Parsing GRIB: 632/5857
# Parsing GRIB: 633/5857
# Parsing GRIB: 634/5857
# Parsing GRIB: 635/5857
# Parsing GRIB: 636/5857
# Parsing GRIB: 637/5857
# Parsing GRIB: 638/5857
# Parsing GRIB: 639/5857
# Parsing GRIB: 640/5857
# Parsing GRIB: 641/5857
# Parsing GRIB: 642/5857
# Parsing GRIB: 643/5857
# Parsing GRIB: 644/5857
# Parsing GRIB: 645/5857
# Parsing GRIB: 646/5857
# Parsing GRIB: 647/5857
# Parsing GRIB: 648/5857
# Parsing GRIB: 649/5857
# Parsing GRIB: 650/5857
# Parsing GRIB: 651/5857
# Parsing GRIB: 652/5857
# Parsing GRIB: 653/5857
# Parsing GRIB: 654/5857
# Parsing GRIB: 655/5857
# Parsing GRIB: 656/5857
# Parsing GRIB: 657/5857
# Parsing GRIB: 658/5857
# Parsing GRIB: 659/5857
# Parsing GRIB: 660/5857
# Parsing GRIB: 661/5857
# Parsing GRIB: 662/5857
# Parsing GRIB: 663/5857
# Parsing GRIB: 664/5857
# Parsing GRIB: 665/5857
# Parsing GRIB: 666/5857
# Parsing GRIB: 667/5857
# Parsing GRIB: 668/5857
# Parsing GRIB: 669/5857
# Parsing GRIB: 670/5857
# Parsing GRIB: 671/5857
# Parsing GRIB: 672/5857
# Parsing GRIB: 673/5857
# Parsing GRIB: 674/5857
# Parsing GRIB: 675/5857
# Parsing GRIB: 676/5857
# Parsing GRIB: 677/5857
# Parsing GRIB: 678/5857
# Parsing GRIB: 679/5857
# Parsing GRIB: 680/5857
# Parsing GRIB: 681/5857
# Parsing GRIB: 682/5857
# Parsing GRIB: 683/5857
# Parsing GRIB: 684/5857
# Parsing GRIB: 685/5857
# Parsing GRIB: 686/5857
# Parsing GRIB: 687/5857
# Parsing GRIB: 688/5857
# Parsing GRIB: 689/5857
# Parsing GRIB: 690/5857
# Parsing GRIB: 691/5857
# Parsing GRIB: 692/5857
# Parsing GRIB: 693/5857
# Parsing GRIB: 694/5857
# Parsing GRIB: 695/5857
# Parsing GRIB: 696/5857
# Parsing GRIB: 697/5857
# Parsing GRIB: 698/5857
# Parsing GRIB: 699/5857
# Parsing GRIB: 700/5857
# Parsing GRIB: 701/5857
# Parsing GRIB: 702/5857
# Parsing GRIB: 703/5857
# Parsing GRIB: 704/5857
# Parsing GRIB: 705/5857
# Parsing GRIB: 706/5857
# Parsing GRIB: 707/5857
# Parsing GRIB: 708/5857
# Parsing GRIB: 709/5857
# Parsing GRIB: 710/5857
# Parsing GRIB: 711/5857
# Parsing GRIB: 712/5857
# Parsing GRIB: 713/5857
# Parsing GRIB: 714/5857
# Parsing GRIB: 715/5857
# Parsing GRIB: 716/5857
# Parsing GRIB: 717/5857
# Parsing GRIB: 718/5857
# Parsing GRIB: 719/5857
# Parsing GRIB: 720/5857
# Parsing GRIB: 721/5857
# Parsing GRIB: 722/5857
# Parsing GRIB: 723/5857
# Parsing GRIB: 724/5857
# Parsing GRIB: 725/5857
# Parsing GRIB: 726/5857
# Parsing GRIB: 727/5857
# Parsing GRIB: 728/5857
# Parsing GRIB: 729/5857
# Parsing GRIB: 730/5857
# Parsing GRIB: 731/5857
# Parsing GRIB: 732/5857
# Parsing GRIB: 733/5857
# Parsing GRIB: 734/5857
# Parsing GRIB: 735/5857
# Parsing GRIB: 736/5857
# Parsing GRIB: 737/5857
# Parsing GRIB: 738/5857
# Parsing GRIB: 739/5857
# Parsing GRIB: 740/5857
# Parsing GRIB: 741/5857
# Parsing GRIB: 742/5857
# Parsing GRIB: 743/5857
# Parsing GRIB: 744/5857
# Parsing GRIB: 745/5857
# Parsing GRIB: 746/5857
# Parsing GRIB: 747/5857
# Parsing GRIB: 748/5857
# Parsing GRIB: 749/5857
# Parsing GRIB: 750/5857
# Parsing GRIB: 751/5857
# Parsing GRIB: 752/5857
# Parsing GRIB: 753/5857
# Parsing GRIB: 754/5857
# Parsing GRIB: 755/5857
# Parsing GRIB: 756/5857
# Parsing GRIB: 757/5857
# Parsing GRIB: 758/5857
# Parsing GRIB: 759/5857
# Parsing GRIB: 760/5857
# Parsing GRIB: 761/5857
# Parsing GRIB: 762/5857
# Parsing GRIB: 763/5857
# Parsing GRIB: 764/5857
# Parsing GRIB: 765/5857
# Parsing GRIB: 766/5857
# Parsing GRIB: 767/5857
# Parsing GRIB: 768/5857
# Parsing GRIB: 769/5857
# Parsing GRIB: 770/5857
# Parsing GRIB: 771/5857
# Parsing GRIB: 772/5857
# Parsing GRIB: 773/5857
# Parsing GRIB: 774/5857
# Parsing GRIB: 775/5857
# Parsing GRIB: 776/5857
# Parsing GRIB: 777/5857
# Parsing GRIB: 778/5857
# Parsing GRIB: 779/5857
# Parsing GRIB: 780/5857
# Parsing GRIB: 781/5857
# Parsing GRIB: 782/5857
# Parsing GRIB: 783/5857
# Parsing GRIB: 784/5857
# Parsing GRIB: 785/5857
# Parsing GRIB: 786/5857
# Parsing GRIB: 787/5857
# Parsing GRIB: 788/5857
# Parsing GRIB: 789/5857
# Parsing GRIB: 790/5857
# Parsing GRIB: 791/5857
# Parsing GRIB: 792/5857
# Parsing GRIB: 793/5857
# Parsing GRIB: 794/5857
# Parsing GRIB: 795/5857
# Parsing GRIB: 796/5857
# Parsing GRIB: 797/5857
# Parsing GRIB: 798/5857
# Parsing GRIB: 799/5857
# Parsing GRIB: 800/5857
# Parsing GRIB: 801/5857
# Parsing GRIB: 802/5857
# Parsing GRIB: 803/5857
# Parsing GRIB: 804/5857
# Parsing GRIB: 805/5857
# Parsing GRIB: 806/5857
# Parsing GRIB: 807/5857
# Parsing GRIB: 808/5857
# Parsing GRIB: 809/5857
# Parsing GRIB: 810/5857
# Parsing GRIB: 811/5857
# Parsing GRIB: 812/5857
# Parsing GRIB: 813/5857
# Parsing GRIB: 814/5857
# Parsing GRIB: 815/5857
# Parsing GRIB: 816/5857
# Parsing GRIB: 817/5857
# Parsing GRIB: 818/5857
# Parsing GRIB: 819/5857
# Parsing GRIB: 820/5857
# Parsing GRIB: 821/5857
# Parsing GRIB: 822/5857
# Parsing GRIB: 823/5857
# Parsing GRIB: 824/5857
# Parsing GRIB: 825/5857
# Parsing GRIB: 826/5857
# Parsing GRIB: 827/5857
# Parsing GRIB: 828/5857
# Parsing GRIB: 829/5857
# Parsing GRIB: 830/5857
# Parsing GRIB: 831/5857
# Parsing GRIB: 832/5857
# Parsing GRIB: 833/5857
# Parsing GRIB: 834/5857
# Parsing GRIB: 835/5857
# Parsing GRIB: 836/5857
# Parsing GRIB: 837/5857
# Parsing GRIB: 838/5857
# Parsing GRIB: 839/5857
# Parsing GRIB: 840/5857
# Parsing GRIB: 841/5857
# Parsing GRIB: 842/5857
# Parsing GRIB: 843/5857
# Parsing GRIB: 844/5857
# Parsing GRIB: 845/5857
# Parsing GRIB: 846/5857
# Parsing GRIB: 847/5857
# Parsing GRIB: 848/5857
# Parsing GRIB: 849/5857
# Parsing GRIB: 850/5857
# Parsing GRIB: 851/5857
# Parsing GRIB: 852/5857
# Parsing GRIB: 853/5857
# Parsing GRIB: 854/5857
# Parsing GRIB: 855/5857
# Parsing GRIB: 856/5857
# Parsing GRIB: 857/5857
# Parsing GRIB: 858/5857
# Parsing GRIB: 859/5857
# Parsing GRIB: 860/5857
# Parsing GRIB: 861/5857
# Parsing GRIB: 862/5857
# Parsing GRIB: 863/5857
# Parsing GRIB: 864/5857
# Parsing GRIB: 865/5857
# Parsing GRIB: 866/5857
# Parsing GRIB: 867/5857
# Parsing GRIB: 868/5857
# Parsing GRIB: 869/5857
# Parsing GRIB: 870/5857
# Parsing GRIB: 871/5857
# Parsing GRIB: 872/5857
# Parsing GRIB: 873/5857
# Parsing GRIB: 874/5857
# Parsing GRIB: 875/5857
# Parsing GRIB: 876/5857
# Parsing GRIB: 877/5857
# Parsing GRIB: 878/5857
# Parsing GRIB: 879/5857
# Parsing GRIB: 880/5857
# Parsing GRIB: 881/5857
# Parsing GRIB: 882/5857
# Parsing GRIB: 883/5857
# Parsing GRIB: 884/5857
# Parsing GRIB: 885/5857
# Parsing GRIB: 886/5857
# Parsing GRIB: 887/5857
# Parsing GRIB: 888/5857
# Parsing GRIB: 889/5857
# Parsing GRIB: 890/5857
# Parsing GRIB: 891/5857
# Parsing GRIB: 892/5857
# Parsing GRIB: 893/5857
# Parsing GRIB: 894/5857
# Parsing GRIB: 895/5857
# Parsing GRIB: 896/5857
# Parsing GRIB: 897/5857
# Parsing GRIB: 898/5857
# Parsing GRIB: 899/5857
# Parsing GRIB: 900/5857
# Parsing GRIB: 901/5857
# Parsing GRIB: 902/5857
# Parsing GRIB: 903/5857
# Parsing GRIB: 904/5857
# Parsing GRIB: 905/5857
# Parsing GRIB: 906/5857
# Parsing GRIB: 907/5857
# Parsing GRIB: 908/5857
# Parsing GRIB: 909/5857
# Parsing GRIB: 910/5857
# Parsing GRIB: 911/5857
# Parsing GRIB: 912/5857
# Parsing GRIB: 913/5857
# Parsing GRIB: 914/5857
# Parsing GRIB: 915/5857
# Parsing GRIB: 916/5857
# Parsing GRIB: 917/5857
# Parsing GRIB: 918/5857
# Parsing GRIB: 919/5857
# Parsing GRIB: 920/5857
# Parsing GRIB: 921/5857
# Parsing GRIB: 922/5857
# Parsing GRIB: 923/5857
# Parsing GRIB: 924/5857
# Parsing GRIB: 925/5857
# Parsing GRIB: 926/5857
# Parsing GRIB: 927/5857
# Parsing GRIB: 928/5857
# Parsing GRIB: 929/5857
# Parsing GRIB: 930/5857
# Parsing GRIB: 931/5857
# Parsing GRIB: 932/5857
# Parsing GRIB: 933/5857
# Parsing GRIB: 934/5857
# Parsing GRIB: 935/5857
# Parsing GRIB: 936/5857
# Parsing GRIB: 937/5857
# Parsing GRIB: 938/5857
# Parsing GRIB: 939/5857
# Parsing GRIB: 940/5857
# Parsing GRIB: 941/5857
# Parsing GRIB: 942/5857
# Parsing GRIB: 943/5857
# Parsing GRIB: 944/5857
# Parsing GRIB: 945/5857
# Parsing GRIB: 946/5857
# Parsing GRIB: 947/5857
# Parsing GRIB: 948/5857
# Parsing GRIB: 949/5857
# Parsing GRIB: 950/5857
# Parsing GRIB: 951/5857
# Parsing GRIB: 952/5857
# Parsing GRIB: 953/5857
# Parsing GRIB: 954/5857
# Parsing GRIB: 955/5857
# Parsing GRIB: 956/5857
# Parsing GRIB: 957/5857
# Parsing GRIB: 958/5857
# Parsing GRIB: 959/5857
# Parsing GRIB: 960/5857
# Parsing GRIB: 961/5857
# Parsing GRIB: 962/5857
# Parsing GRIB: 963/5857
# Parsing GRIB: 964/5857
# Parsing GRIB: 965/5857
# Parsing GRIB: 966/5857
# Parsing GRIB: 967/5857
# Parsing GRIB: 968/5857
# Parsing GRIB: 969/5857
# Parsing GRIB: 970/5857
# Parsing GRIB: 971/5857
# Parsing GRIB: 972/5857
# Parsing GRIB: 973/5857
# Parsing GRIB: 974/5857
# Parsing GRIB: 975/5857
# Parsing GRIB: 976/5857
# Parsing GRIB: 977/5857
# Parsing GRIB: 978/5857
# Parsing GRIB: 979/5857
# Parsing GRIB: 980/5857
# Parsing GRIB: 981/5857
# Parsing GRIB: 982/5857
# Parsing GRIB: 983/5857
# Parsing GRIB: 984/5857
# Parsing GRIB: 985/5857
# Parsing GRIB: 986/5857
# Parsing GRIB: 987/5857
# Parsing GRIB: 988/5857
# Parsing GRIB: 989/5857
# Parsing GRIB: 990/5857
# Parsing GRIB: 991/5857
# Parsing GRIB: 992/5857
# Parsing GRIB: 993/5857
# Parsing GRIB: 994/5857
# Parsing GRIB: 995/5857
# Parsing GRIB: 996/5857
# Parsing GRIB: 997/5857
# Parsing GRIB: 998/5857
# Parsing GRIB: 999/5857
# Parsing GRIB: 1000/5857
# Parsing GRIB: 1001/5857
# Parsing GRIB: 1002/5857
# Parsing GRIB: 1003/5857
# Parsing GRIB: 1004/5857
# Parsing GRIB: 1005/5857
# Parsing GRIB: 1006/5857
# Parsing GRIB: 1007/5857
# Parsing GRIB: 1008/5857
# Parsing GRIB: 1009/5857
# Parsing GRIB: 1010/5857
# Parsing GRIB: 1011/5857
# Parsing GRIB: 1012/5857
# Parsing GRIB: 1013/5857
# Parsing GRIB: 1014/5857
# Parsing GRIB: 1015/5857
# Parsing GRIB: 1016/5857
# Parsing GRIB: 1017/5857
# Parsing GRIB: 1018/5857
# Parsing GRIB: 1019/5857
# Parsing GRIB: 1020/5857
# Parsing GRIB: 1021/5857
# Parsing GRIB: 1022/5857
# Parsing GRIB: 1023/5857
# Parsing GRIB: 1024/5857
# Parsing GRIB: 1025/5857
# Parsing GRIB: 1026/5857
# Parsing GRIB: 1027/5857
# Parsing GRIB: 1028/5857
# Parsing GRIB: 1029/5857
# Parsing GRIB: 1030/5857
# Parsing GRIB: 1031/5857
# Parsing GRIB: 1032/5857
# Parsing GRIB: 1033/5857
# Parsing GRIB: 1034/5857
# Parsing GRIB: 1035/5857
# Parsing GRIB: 1036/5857
# Parsing GRIB: 1037/5857
# Parsing GRIB: 1038/5857
# Parsing GRIB: 1039/5857
# Parsing GRIB: 1040/5857
# Parsing GRIB: 1041/5857
# Parsing GRIB: 1042/5857
# Parsing GRIB: 1043/5857
# Parsing GRIB: 1044/5857
# Parsing GRIB: 1045/5857
# Parsing GRIB: 1046/5857
# Parsing GRIB: 1047/5857
# Parsing GRIB: 1048/5857
# Parsing GRIB: 1049/5857
# Parsing GRIB: 1050/5857
# Parsing GRIB: 1051/5857
# Parsing GRIB: 1052/5857
# Parsing GRIB: 1053/5857
# Parsing GRIB: 1054/5857
# Parsing GRIB: 1055/5857
# Parsing GRIB: 1056/5857
# Parsing GRIB: 1057/5857
# Parsing GRIB: 1058/5857
# Parsing GRIB: 1059/5857
# Parsing GRIB: 1060/5857
# Parsing GRIB: 1061/5857
# Parsing GRIB: 1062/5857
# Parsing GRIB: 1063/5857
# Parsing GRIB: 1064/5857
# Parsing GRIB: 1065/5857
# Parsing GRIB: 1066/5857
# Parsing GRIB: 1067/5857
# Parsing GRIB: 1068/5857
# Parsing GRIB: 1069/5857
# Parsing GRIB: 1070/5857
# Parsing GRIB: 1071/5857
# Parsing GRIB: 1072/5857
# Parsing GRIB: 1073/5857
# Parsing GRIB: 1074/5857
# Parsing GRIB: 1075/5857
# Parsing GRIB: 1076/5857
# Attempt 0/10: Could not download Product MSG3-SEVI-MSGCLMK-0100-0100-20230720191500.000000000Z-NA of Collection EO:EUM:DAT:MSG:CLM
# Parsing GRIB: 1077/5857
# Parsing GRIB: 1078/5857
# Parsing GRIB: 1079/5857
# Parsing GRIB: 1080/5857
# Parsing GRIB: 1081/5857
# Parsing GRIB: 1082/5857
# Parsing GRIB: 1083/5857
# Parsing GRIB: 1084/5857
# Parsing GRIB: 1085/5857
# Parsing GRIB: 1086/5857
# Parsing GRIB: 1087/5857
# Parsing GRIB: 1088/5857
# Parsing GRIB: 1089/5857
# Parsing GRIB: 1090/5857
# Parsing GRIB: 1091/5857
# Parsing GRIB: 1092/5857
# Parsing GRIB: 1093/5857
# Parsing GRIB: 1094/5857
# Parsing GRIB: 1095/5857
# Parsing GRIB: 1096/5857
# Parsing GRIB: 1097/5857
# Parsing GRIB: 1098/5857
# Parsing GRIB: 1099/5857
# Parsing GRIB: 1100/5857
# Parsing GRIB: 1101/5857
# Parsing GRIB: 1102/5857
# Parsing GRIB: 1103/5857
# Parsing GRIB: 1104/5857
# Parsing GRIB: 1105/5857
# Parsing GRIB: 1106/5857
# Parsing GRIB: 1107/5857
# Parsing GRIB: 1108/5857
# Parsing GRIB: 1109/5857
# Parsing GRIB: 1110/5857
# Parsing GRIB: 1111/5857
# Parsing GRIB: 1112/5857
# Parsing GRIB: 1113/5857
# Parsing GRIB: 1114/5857
# Parsing GRIB: 1115/5857
# Parsing GRIB: 1116/5857
# Parsing GRIB: 1117/5857
# Parsing GRIB: 1118/5857
# Parsing GRIB: 1119/5857
# Parsing GRIB: 1120/5857
# Parsing GRIB: 1121/5857
# Parsing GRIB: 1122/5857
# Parsing GRIB: 1123/5857
# Parsing GRIB: 1124/5857
# Parsing GRIB: 1125/5857
# Parsing GRIB: 1126/5857
# Parsing GRIB: 1127/5857
# Parsing GRIB: 1128/5857
# Parsing GRIB: 1129/5857
# Parsing GRIB: 1130/5857
# Parsing GRIB: 1131/5857
# Parsing GRIB: 1132/5857
# Parsing GRIB: 1133/5857
# Parsing GRIB: 1134/5857
# Parsing GRIB: 1135/5857
# Parsing GRIB: 1136/5857
# Parsing GRIB: 1137/5857
# Parsing GRIB: 1138/5857
# Parsing GRIB: 1139/5857
# Parsing GRIB: 1140/5857
# Parsing GRIB: 1141/5857
# Parsing GRIB: 1142/5857
# Parsing GRIB: 1143/5857
# Parsing GRIB: 1144/5857
# Parsing GRIB: 1145/5857
# Parsing GRIB: 1146/5857
# Parsing GRIB: 1147/5857
# Parsing GRIB: 1148/5857
# Parsing GRIB: 1149/5857
# Parsing GRIB: 1150/5857
# Parsing GRIB: 1151/5857
# Parsing GRIB: 1152/5857
# Parsing GRIB: 1153/5857
# Parsing GRIB: 1154/5857
# Parsing GRIB: 1155/5857
# Parsing GRIB: 1156/5857
# Parsing GRIB: 1157/5857
# Parsing GRIB: 1158/5857
# Parsing GRIB: 1159/5857
# Parsing GRIB: 1160/5857
# Parsing GRIB: 1161/5857
# Parsing GRIB: 1162/5857
# Parsing GRIB: 1163/5857
# Parsing GRIB: 1164/5857
# Parsing GRIB: 1165/5857
# Parsing GRIB: 1166/5857
# Parsing GRIB: 1167/5857
# Parsing GRIB: 1168/5857
# Parsing GRIB: 1169/5857
# Parsing GRIB: 1170/5857
# Parsing GRIB: 1171/5857
# Parsing GRIB: 1172/5857
# Parsing GRIB: 1173/5857
# Parsing GRIB: 1174/5857
# Parsing GRIB: 1175/5857
# Parsing GRIB: 1176/5857
# Parsing GRIB: 1177/5857
# Parsing GRIB: 1178/5857
# Parsing GRIB: 1179/5857
# Parsing GRIB: 1180/5857
# Parsing GRIB: 1181/5857
# Parsing GRIB: 1182/5857
# Parsing GRIB: 1183/5857
# Parsing GRIB: 1184/5857
# Parsing GRIB: 1185/5857
# Parsing GRIB: 1186/5857
# Parsing GRIB: 1187/5857
# Parsing GRIB: 1188/5857
# Parsing GRIB: 1189/5857
# Parsing GRIB: 1190/5857
# Parsing GRIB: 1191/5857
# Parsing GRIB: 1192/5857
# Parsing GRIB: 1193/5857
# Parsing GRIB: 1194/5857
# Parsing GRIB: 1195/5857
# Parsing GRIB: 1196/5857
# Parsing GRIB: 1197/5857
# Parsing GRIB: 1198/5857
# Parsing GRIB: 1199/5857
# Parsing GRIB: 1200/5857
# Parsing GRIB: 1201/5857
# Parsing GRIB: 1202/5857
# Parsing GRIB: 1203/5857
# Parsing GRIB: 1204/5857
# Parsing GRIB: 1205/5857
# Parsing GRIB: 1206/5857
# Parsing GRIB: 1207/5857
# Parsing GRIB: 1208/5857
# Parsing GRIB: 1209/5857
# Parsing GRIB: 1210/5857
# Parsing GRIB: 1211/5857
# Parsing GRIB: 1212/5857
# Parsing GRIB: 1213/5857
# Parsing GRIB: 1214/5857
# Parsing GRIB: 1215/5857
# Parsing GRIB: 1216/5857
# Parsing GRIB: 1217/5857
# Parsing GRIB: 1218/5857
# Parsing GRIB: 1219/5857
# Parsing GRIB: 1220/5857
# Parsing GRIB: 1221/5857
# Parsing GRIB: 1222/5857
# Parsing GRIB: 1223/5857
# Parsing GRIB: 1224/5857
# Parsing GRIB: 1225/5857
# Parsing GRIB: 1226/5857
# Parsing GRIB: 1227/5857
# Parsing GRIB: 1228/5857
# Parsing GRIB: 1229/5857
# Parsing GRIB: 1230/5857
# Parsing GRIB: 1231/5857
# Parsing GRIB: 1232/5857
# Parsing GRIB: 1233/5857
# Parsing GRIB: 1234/5857
# Parsing GRIB: 1235/5857
# Parsing GRIB: 1236/5857
# Parsing GRIB: 1237/5857
# Parsing GRIB: 1238/5857
# Parsing GRIB: 1239/5857
# Parsing GRIB: 1240/5857
# Parsing GRIB: 1241/5857
# Parsing GRIB: 1242/5857
# Parsing GRIB: 1243/5857
# Parsing GRIB: 1244/5857
# Parsing GRIB: 1245/5857
# Parsing GRIB: 1246/5857
# Parsing GRIB: 1247/5857
# Parsing GRIB: 1248/5857
# Parsing GRIB: 1249/5857
# Parsing GRIB: 1250/5857
# Parsing GRIB: 1251/5857
# Parsing GRIB: 1252/5857
# Parsing GRIB: 1253/5857
# Parsing GRIB: 1254/5857
# Parsing GRIB: 1255/5857
# Parsing GRIB: 1256/5857
# Parsing GRIB: 1257/5857
# Parsing GRIB: 1258/5857
# Parsing GRIB: 1259/5857
# Parsing GRIB: 1260/5857
# Parsing GRIB: 1261/5857
# Parsing GRIB: 1262/5857
# Parsing GRIB: 1263/5857
# Parsing GRIB: 1264/5857
# Parsing GRIB: 1265/5857
# Parsing GRIB: 1266/5857
# Parsing GRIB: 1267/5857
# Parsing GRIB: 1268/5857
# Parsing GRIB: 1269/5857
# Parsing GRIB: 1270/5857
# Parsing GRIB: 1271/5857
# Parsing GRIB: 1272/5857
# Parsing GRIB: 1273/5857
# Parsing GRIB: 1274/5857
# Parsing GRIB: 1275/5857
# Parsing GRIB: 1276/5857
# Parsing GRIB: 1277/5857
# Parsing GRIB: 1278/5857
# Parsing GRIB: 1279/5857
# Parsing GRIB: 1280/5857
# Parsing GRIB: 1281/5857
# Parsing GRIB: 1282/5857
# Parsing GRIB: 1283/5857
# Parsing GRIB: 1284/5857
# Parsing GRIB: 1285/5857
# Parsing GRIB: 1286/5857
# Parsing GRIB: 1287/5857
# Parsing GRIB: 1288/5857
# Parsing GRIB: 1289/5857
# Parsing GRIB: 1290/5857
# Parsing GRIB: 1291/5857
# Parsing GRIB: 1292/5857
# Parsing GRIB: 1293/5857
# Parsing GRIB: 1294/5857
# Parsing GRIB: 1295/5857
# Parsing GRIB: 1296/5857
# Parsing GRIB: 1297/5857
# Parsing GRIB: 1298/5857
# Parsing GRIB: 1299/5857
# Parsing GRIB: 1300/5857
# Parsing GRIB: 1301/5857
# Parsing GRIB: 1302/5857
# Parsing GRIB: 1303/5857
# Parsing GRIB: 1304/5857
# Parsing GRIB: 1305/5857
# Parsing GRIB: 1306/5857
# Parsing GRIB: 1307/5857
# Parsing GRIB: 1308/5857
# Parsing GRIB: 1309/5857
# Parsing GRIB: 1310/5857
# Parsing GRIB: 1311/5857
# Parsing GRIB: 1312/5857
# Parsing GRIB: 1313/5857
# Parsing GRIB: 1314/5857
# Parsing GRIB: 1315/5857
# Parsing GRIB: 1316/5857
# Parsing GRIB: 1317/5857
# Parsing GRIB: 1318/5857
# Parsing GRIB: 1319/5857
# Parsing GRIB: 1320/5857
# Parsing GRIB: 1321/5857
# Parsing GRIB: 1322/5857
# Parsing GRIB: 1323/5857
# Parsing GRIB: 1324/5857
# Parsing GRIB: 1325/5857
# Parsing GRIB: 1326/5857
# Parsing GRIB: 1327/5857
# Parsing GRIB: 1328/5857
# Parsing GRIB: 1329/5857
# Parsing GRIB: 1330/5857
# Parsing GRIB: 1331/5857
# Parsing GRIB: 1332/5857
# Parsing GRIB: 1333/5857
# Parsing GRIB: 1334/5857
# Parsing GRIB: 1335/5857
# Parsing GRIB: 1336/5857
# Parsing GRIB: 1337/5857
# Parsing GRIB: 1338/5857
# Parsing GRIB: 1339/5857
# Parsing GRIB: 1340/5857
# Parsing GRIB: 1341/5857
# Parsing GRIB: 1342/5857
# Parsing GRIB: 1343/5857
# Parsing GRIB: 1344/5857
# Parsing GRIB: 1345/5857
# Parsing GRIB: 1346/5857
# Parsing GRIB: 1347/5857
# Parsing GRIB: 1348/5857
# Parsing GRIB: 1349/5857
# Parsing GRIB: 1350/5857
# Parsing GRIB: 1351/5857
# Parsing GRIB: 1352/5857
# Parsing GRIB: 1353/5857
# Parsing GRIB: 1354/5857
# Parsing GRIB: 1355/5857
# Parsing GRIB: 1356/5857
# Parsing GRIB: 1357/5857
# Parsing GRIB: 1358/5857
# Parsing GRIB: 1359/5857
# Parsing GRIB: 1360/5857
# Parsing GRIB: 1361/5857
# Parsing GRIB: 1362/5857
# Parsing GRIB: 1363/5857
# Parsing GRIB: 1364/5857
# Parsing GRIB: 1365/5857
# Parsing GRIB: 1366/5857
# Parsing GRIB: 1367/5857
# Parsing GRIB: 1368/5857
# Parsing GRIB: 1369/5857
# Parsing GRIB: 1370/5857
# Parsing GRIB: 1371/5857
# Parsing GRIB: 1372/5857
# Parsing GRIB: 1373/5857
# Parsing GRIB: 1374/5857
# Parsing GRIB: 1375/5857
# Parsing GRIB: 1376/5857
# Parsing GRIB: 1377/5857
# Parsing GRIB: 1378/5857
# Parsing GRIB: 1379/5857
# Parsing GRIB: 1380/5857
# Parsing GRIB: 1381/5857
# Parsing GRIB: 1382/5857
# Parsing GRIB: 1383/5857
# Parsing GRIB: 1384/5857
# Parsing GRIB: 1385/5857
# Parsing GRIB: 1386/5857
# Parsing GRIB: 1387/5857
# Parsing GRIB: 1388/5857
# Parsing GRIB: 1389/5857
# Parsing GRIB: 1390/5857
# Parsing GRIB: 1391/5857
# Parsing GRIB: 1392/5857
# Parsing GRIB: 1393/5857
# Parsing GRIB: 1394/5857
# Parsing GRIB: 1395/5857
# Parsing GRIB: 1396/5857
# Parsing GRIB: 1397/5857
# Parsing GRIB: 1398/5857
# Parsing GRIB: 1399/5857
# Parsing GRIB: 1400/5857
# Parsing GRIB: 1401/5857
# Parsing GRIB: 1402/5857
# Parsing GRIB: 1403/5857
# Parsing GRIB: 1404/5857
# Parsing GRIB: 1405/5857
# Parsing GRIB: 1406/5857
# Parsing GRIB: 1407/5857
# Parsing GRIB: 1408/5857
# Parsing GRIB: 1409/5857
# Parsing GRIB: 1410/5857
# Parsing GRIB: 1411/5857
# Parsing GRIB: 1412/5857
# Parsing GRIB: 1413/5857
# Parsing GRIB: 1414/5857
# Parsing GRIB: 1415/5857
# Parsing GRIB: 1416/5857
# Parsing GRIB: 1417/5857
# Parsing GRIB: 1418/5857
# Parsing GRIB: 1419/5857
# Parsing GRIB: 1420/5857
# Parsing GRIB: 1421/5857
# Parsing GRIB: 1422/5857
# Parsing GRIB: 1423/5857
# Parsing GRIB: 1424/5857
# Parsing GRIB: 1425/5857
# Parsing GRIB: 1426/5857
# Parsing GRIB: 1427/5857
# Parsing GRIB: 1428/5857
# Parsing GRIB: 1429/5857
# Parsing GRIB: 1430/5857
# Parsing GRIB: 1431/5857
# Parsing GRIB: 1432/5857
# Parsing GRIB: 1433/5857
# Parsing GRIB: 1434/5857
# Parsing GRIB: 1435/5857
# Parsing GRIB: 1436/5857
# Parsing GRIB: 1437/5857
# Parsing GRIB: 1438/5857
# Parsing GRIB: 1439/5857
# Parsing GRIB: 1440/5857
# Parsing GRIB: 1441/5857
# Parsing GRIB: 1442/5857
# Parsing GRIB: 1443/5857
# Parsing GRIB: 1444/5857
# Parsing GRIB: 1445/5857
# Parsing GRIB: 1446/5857
# Parsing GRIB: 1447/5857
# Parsing GRIB: 1448/5857
# Parsing GRIB: 1449/5857
# Parsing GRIB: 1450/5857
# Parsing GRIB: 1451/5857
# Parsing GRIB: 1452/5857
# Parsing GRIB: 1453/5857
# Parsing GRIB: 1454/5857
# Parsing GRIB: 1455/5857
# Parsing GRIB: 1456/5857
# Parsing GRIB: 1457/5857
# Parsing GRIB: 1458/5857
# Parsing GRIB: 1459/5857
# Parsing GRIB: 1460/5857
# Parsing GRIB: 1461/5857
# Parsing GRIB: 1462/5857
# Parsing GRIB: 1463/5857
# Parsing GRIB: 1464/5857
# Parsing GRIB: 1465/5857
# Parsing GRIB: 1466/5857
# Parsing GRIB: 1467/5857
# Parsing GRIB: 1468/5857
# Parsing GRIB: 1469/5857
# Parsing GRIB: 1470/5857
# Parsing GRIB: 1471/5857
# Parsing GRIB: 1472/5857
# Parsing GRIB: 1473/5857
# Parsing GRIB: 1474/5857
# Parsing GRIB: 1475/5857
# Parsing GRIB: 1476/5857
# Parsing GRIB: 1477/5857
# Parsing GRIB: 1478/5857
# Parsing GRIB: 1479/5857
# Parsing GRIB: 1480/5857
# Parsing GRIB: 1481/5857
# Parsing GRIB: 1482/5857
# Parsing GRIB: 1483/5857
# Parsing GRIB: 1484/5857
# Parsing GRIB: 1485/5857
# Parsing GRIB: 1486/5857
# Parsing GRIB: 1487/5857
# Parsing GRIB: 1488/5857
# Parsing GRIB: 1489/5857
# Parsing GRIB: 1490/5857
# Parsing GRIB: 1491/5857
# Parsing GRIB: 1492/5857
# Parsing GRIB: 1493/5857
# Parsing GRIB: 1494/5857
# Parsing GRIB: 1495/5857
# Parsing GRIB: 1496/5857
# Parsing GRIB: 1497/5857
# Parsing GRIB: 1498/5857
# Parsing GRIB: 1499/5857
# Parsing GRIB: 1500/5857
# Parsing GRIB: 1501/5857
# Parsing GRIB: 1502/5857
# Parsing GRIB: 1503/5857
# Parsing GRIB: 1504/5857
# Parsing GRIB: 1505/5857
# Parsing GRIB: 1506/5857
# Parsing GRIB: 1507/5857
# Parsing GRIB: 1508/5857
# Parsing GRIB: 1509/5857
# Parsing GRIB: 1510/5857
# Parsing GRIB: 1511/5857
# Parsing GRIB: 1512/5857
# Parsing GRIB: 1513/5857
# Parsing GRIB: 1514/5857
# Parsing GRIB: 1515/5857
# Parsing GRIB: 1516/5857
# Parsing GRIB: 1517/5857
# Parsing GRIB: 1518/5857
# Parsing GRIB: 1519/5857
# Parsing GRIB: 1520/5857
# Parsing GRIB: 1521/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230716040000.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230716040000.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc391548f10>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 1522/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230716034500.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230716034500.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc3916ef280>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 1523/5857
# Parsing GRIB: 1524/5857
# Parsing GRIB: 1525/5857
# Parsing GRIB: 1526/5857
# Parsing GRIB: 1527/5857
# Parsing GRIB: 1528/5857
# Parsing GRIB: 1529/5857
# Parsing GRIB: 1530/5857
# Parsing GRIB: 1531/5857
# Parsing GRIB: 1532/5857
# Parsing GRIB: 1533/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230716010000.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230716010000.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc39167d280>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 1534/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230716004500.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230716004500.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc3916f1280>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 1535/5857
# Parsing GRIB: 1536/5857
# Parsing GRIB: 1537/5857
# Parsing GRIB: 1538/5857
# Parsing GRIB: 1539/5857
# Parsing GRIB: 1540/5857
# Parsing GRIB: 1541/5857
# Parsing GRIB: 1542/5857
# Parsing GRIB: 1543/5857
# Parsing GRIB: 1544/5857
# Parsing GRIB: 1545/5857
# Parsing GRIB: 1546/5857
# Parsing GRIB: 1547/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230715213000.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230715213000.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc3916f8280>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 1548/5857
# Parsing GRIB: 1549/5857
# Parsing GRIB: 1550/5857
# Parsing GRIB: 1551/5857
# Parsing GRIB: 1552/5857
# Parsing GRIB: 1553/5857
# Parsing GRIB: 1554/5857
# Parsing GRIB: 1555/5857
# Parsing GRIB: 1556/5857
# Parsing GRIB: 1557/5857
# Parsing GRIB: 1558/5857
# Parsing GRIB: 1559/5857
# Parsing GRIB: 1560/5857
# Parsing GRIB: 1561/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230715180000.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230715180000.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc391667dc0>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 1562/5857
# Parsing GRIB: 1563/5857
# Parsing GRIB: 1564/5857
# Parsing GRIB: 1565/5857
# Parsing GRIB: 1566/5857
# Parsing GRIB: 1567/5857
# Parsing GRIB: 1568/5857
# Parsing GRIB: 1569/5857
# Parsing GRIB: 1570/5857
# Parsing GRIB: 1571/5857
# Parsing GRIB: 1572/5857
# Parsing GRIB: 1573/5857
# Parsing GRIB: 1574/5857
# Parsing GRIB: 1575/5857
# Parsing GRIB: 1576/5857
# Parsing GRIB: 1577/5857
# Parsing GRIB: 1578/5857
# Parsing GRIB: 1579/5857
# Parsing GRIB: 1580/5857
# Parsing GRIB: 1581/5857
# Parsing GRIB: 1582/5857
# Parsing GRIB: 1583/5857
# Parsing GRIB: 1584/5857
# Parsing GRIB: 1585/5857
# Parsing GRIB: 1586/5857
# Parsing GRIB: 1587/5857
# Parsing GRIB: 1588/5857
# Parsing GRIB: 1589/5857
# Parsing GRIB: 1590/5857
# Parsing GRIB: 1591/5857
# Parsing GRIB: 1592/5857
# Parsing GRIB: 1593/5857
# Parsing GRIB: 1594/5857
# Parsing GRIB: 1595/5857
# Parsing GRIB: 1596/5857
# Parsing GRIB: 1597/5857
# Parsing GRIB: 1598/5857
# Parsing GRIB: 1599/5857
# Parsing GRIB: 1600/5857
# Parsing GRIB: 1601/5857
# Parsing GRIB: 1602/5857
# Parsing GRIB: 1603/5857
# Parsing GRIB: 1604/5857
# Parsing GRIB: 1605/5857
# Parsing GRIB: 1606/5857
# Parsing GRIB: 1607/5857
# Parsing GRIB: 1608/5857
# Parsing GRIB: 1609/5857
# Parsing GRIB: 1610/5857
# Parsing GRIB: 1611/5857
# Parsing GRIB: 1612/5857
# Parsing GRIB: 1613/5857
# Parsing GRIB: 1614/5857
# Parsing GRIB: 1615/5857
# Parsing GRIB: 1616/5857
# Parsing GRIB: 1617/5857
# Parsing GRIB: 1618/5857
# Parsing GRIB: 1619/5857
# Parsing GRIB: 1620/5857
# Parsing GRIB: 1621/5857
# Parsing GRIB: 1622/5857
# Parsing GRIB: 1623/5857
# Parsing GRIB: 1624/5857
# Parsing GRIB: 1625/5857
# Parsing GRIB: 1626/5857
# Parsing GRIB: 1627/5857
# Parsing GRIB: 1628/5857
# Parsing GRIB: 1629/5857
# Parsing GRIB: 1630/5857
# Parsing GRIB: 1631/5857
# Parsing GRIB: 1632/5857
# Parsing GRIB: 1633/5857
# Parsing GRIB: 1634/5857
# Parsing GRIB: 1635/5857
# Parsing GRIB: 1636/5857
# Parsing GRIB: 1637/5857
# Parsing GRIB: 1638/5857
# Parsing GRIB: 1639/5857
# Parsing GRIB: 1640/5857
# Parsing GRIB: 1641/5857
# Parsing GRIB: 1642/5857
# Parsing GRIB: 1643/5857
# Parsing GRIB: 1644/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230714211500.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230714211500.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc39166c160>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 1645/5857
# Parsing GRIB: 1646/5857
# Parsing GRIB: 1647/5857
# Parsing GRIB: 1648/5857
# Parsing GRIB: 1649/5857
# Parsing GRIB: 1650/5857
# Parsing GRIB: 1651/5857
# Parsing GRIB: 1652/5857
# Parsing GRIB: 1653/5857
# Parsing GRIB: 1654/5857
# Parsing GRIB: 1655/5857
# Parsing GRIB: 1656/5857
# Parsing GRIB: 1657/5857
# Parsing GRIB: 1658/5857
# Parsing GRIB: 1659/5857
# Parsing GRIB: 1660/5857
# Parsing GRIB: 1661/5857
# Parsing GRIB: 1662/5857
# Parsing GRIB: 1663/5857
# Parsing GRIB: 1664/5857
# Parsing GRIB: 1665/5857
# Parsing GRIB: 1666/5857
# Parsing GRIB: 1667/5857
# Parsing GRIB: 1668/5857
# Parsing GRIB: 1669/5857
# Parsing GRIB: 1670/5857
# Parsing GRIB: 1671/5857
# Parsing GRIB: 1672/5857
# Parsing GRIB: 1673/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230714140000.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230714140000.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc3916f1d60>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 1674/5857
# Parsing GRIB: 1675/5857
# Parsing GRIB: 1676/5857
# Parsing GRIB: 1677/5857
# Parsing GRIB: 1678/5857
# Parsing GRIB: 1679/5857
# Parsing GRIB: 1680/5857
# Parsing GRIB: 1681/5857
# Parsing GRIB: 1682/5857
# Parsing GRIB: 1683/5857
# Parsing GRIB: 1684/5857
# Parsing GRIB: 1685/5857
# Parsing GRIB: 1686/5857
# Parsing GRIB: 1687/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230714103000.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230714103000.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc39166c550>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 1688/5857
# Parsing GRIB: 1689/5857
# Parsing GRIB: 1690/5857
# Parsing GRIB: 1691/5857
# Parsing GRIB: 1692/5857
# Parsing GRIB: 1693/5857
# Parsing GRIB: 1694/5857
# Parsing GRIB: 1695/5857
# Parsing GRIB: 1696/5857
# Parsing GRIB: 1697/5857
# Parsing GRIB: 1698/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230714074500.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230714074500.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc3916fb2b0>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 1699/5857
# Parsing GRIB: 1700/5857
# Parsing GRIB: 1701/5857
# Parsing GRIB: 1702/5857
# Parsing GRIB: 1703/5857
# Parsing GRIB: 1704/5857
# Parsing GRIB: 1705/5857
# Parsing GRIB: 1706/5857
# Parsing GRIB: 1707/5857
# Parsing GRIB: 1708/5857
# Parsing GRIB: 1709/5857
# Parsing GRIB: 1710/5857
# Parsing GRIB: 1711/5857
# Parsing GRIB: 1712/5857
# Parsing GRIB: 1713/5857
# Parsing GRIB: 1714/5857
# Parsing GRIB: 1715/5857
# Parsing GRIB: 1716/5857
# Parsing GRIB: 1717/5857
# Parsing GRIB: 1718/5857
# Parsing GRIB: 1719/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230714023000.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230714023000.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc391667670>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 1720/5857
# Parsing GRIB: 1721/5857
# Parsing GRIB: 1722/5857
# Parsing GRIB: 1723/5857
# Parsing GRIB: 1724/5857
# Parsing GRIB: 1725/5857
# Parsing GRIB: 1726/5857
# Parsing GRIB: 1727/5857
# Parsing GRIB: 1728/5857
# Parsing GRIB: 1729/5857
# Parsing GRIB: 1730/5857
# Parsing GRIB: 1731/5857
# Parsing GRIB: 1732/5857
# Parsing GRIB: 1733/5857
# Parsing GRIB: 1734/5857
# Parsing GRIB: 1735/5857
# Parsing GRIB: 1736/5857
# Parsing GRIB: 1737/5857
# Parsing GRIB: 1738/5857
# Parsing GRIB: 1739/5857
# Parsing GRIB: 1740/5857
# Parsing GRIB: 1741/5857
# Parsing GRIB: 1742/5857
# Parsing GRIB: 1743/5857
# Parsing GRIB: 1744/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230713201500.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230713201500.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc391548340>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Attempt 1/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230713201500.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230713201500.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc2e00f7190>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 1745/5857
# Parsing GRIB: 1746/5857
# Parsing GRIB: 1747/5857
# Parsing GRIB: 1748/5857
# Parsing GRIB: 1749/5857
# Parsing GRIB: 1750/5857
# Parsing GRIB: 1751/5857
# Parsing GRIB: 1752/5857
# Parsing GRIB: 1753/5857
# Parsing GRIB: 1754/5857
# Parsing GRIB: 1755/5857
# Parsing GRIB: 1756/5857
# Parsing GRIB: 1757/5857
# Parsing GRIB: 1758/5857
# Parsing GRIB: 1759/5857
# Parsing GRIB: 1760/5857
# Parsing GRIB: 1761/5857
# Parsing GRIB: 1762/5857
# Parsing GRIB: 1763/5857
# Parsing GRIB: 1764/5857
# Parsing GRIB: 1765/5857
# Parsing GRIB: 1766/5857
# Parsing GRIB: 1767/5857
# Parsing GRIB: 1768/5857
# Parsing GRIB: 1769/5857
# Parsing GRIB: 1770/5857
# Parsing GRIB: 1771/5857
# Parsing GRIB: 1772/5857
# Parsing GRIB: 1773/5857
# Parsing GRIB: 1774/5857
# Parsing GRIB: 1775/5857
# Parsing GRIB: 1776/5857
# Parsing GRIB: 1777/5857
# Parsing GRIB: 1778/5857
# Parsing GRIB: 1779/5857
# Parsing GRIB: 1780/5857
# Parsing GRIB: 1781/5857
# Parsing GRIB: 1782/5857
# Parsing GRIB: 1783/5857
# Parsing GRIB: 1784/5857
# Parsing GRIB: 1785/5857
# Parsing GRIB: 1786/5857
# Parsing GRIB: 1787/5857
# Parsing GRIB: 1788/5857
# ...
# Parsing GRIB: 2960/5857
# Parsing GRIB: 2961/5857
# Parsing GRIB: 2962/5857
# Parsing GRIB: 2963/5857
# Parsing GRIB: 2964/5857
# Parsing GRIB: 2965/5857
# Parsing GRIB: 2966/5857
# Parsing GRIB: 2967/5857
# Parsing GRIB: 2968/5857
# Parsing GRIB: 2969/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230701020000.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230701020000.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc39166cf40>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 2970/5857
# Parsing GRIB: 2971/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230701013000.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230701013000.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc39166c4c0>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 2972/5857
# Parsing GRIB: 2973/5857
# Parsing GRIB: 2974/5857
# Parsing GRIB: 2975/5857
# Parsing GRIB: 2976/5857
# Parsing GRIB: 2977/5857
# Parsing GRIB: 2978/5857
# Parsing GRIB: 2979/5857
# Parsing GRIB: 2980/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230630231500.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230630231500.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc39167d790>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 2981/5857
# Parsing GRIB: 2982/5857
# Parsing GRIB: 2983/5857
# Parsing GRIB: 2984/5857
# Parsing GRIB: 2985/5857
# Parsing GRIB: 2986/5857
# Parsing GRIB: 2987/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230630213000.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230630213000.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc391667190>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 2988/5857
# Parsing GRIB: 2989/5857
# Parsing GRIB: 2990/5857
# Parsing GRIB: 2991/5857
# Parsing GRIB: 2992/5857
# Parsing GRIB: 2993/5857
# Parsing GRIB: 2994/5857
# Parsing GRIB: 2995/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230630193000.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230630193000.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc2e013f100>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 2996/5857
# Parsing GRIB: 2997/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230630190000.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230630190000.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc2e013fd00>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 2998/5857
# Parsing GRIB: 2999/5857
# Parsing GRIB: 3000/5857
# Parsing GRIB: 3001/5857
# Parsing GRIB: 3002/5857
# Parsing GRIB: 3003/5857
# Parsing GRIB: 3004/5857
# Parsing GRIB: 3005/5857
# Parsing GRIB: 3006/5857
# Parsing GRIB: 3007/5857
# Parsing GRIB: 3008/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230630161500.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230630161500.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc39166c6a0>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 3009/5857
# Parsing GRIB: 3010/5857
# Parsing GRIB: 3011/5857
# Parsing GRIB: 3012/5857
# Parsing GRIB: 3013/5857
# Parsing GRIB: 3014/5857
# Parsing GRIB: 3015/5857
# Parsing GRIB: 3016/5857
# Parsing GRIB: 3017/5857
# Parsing GRIB: 3018/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230630134500.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230630134500.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc3916f1880>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 3019/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230630133000.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230630133000.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc3916f1040>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 3020/5857
# Parsing GRIB: 3021/5857
# Parsing GRIB: 3022/5857
# Parsing GRIB: 3023/5857
# Parsing GRIB: 3024/5857
# Parsing GRIB: 3025/5857
# Parsing GRIB: 3026/5857
# Parsing GRIB: 3027/5857
# Parsing GRIB: 3028/5857
# Parsing GRIB: 3029/5857
# Parsing GRIB: 3030/5857
# Parsing GRIB: 3031/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230630103000.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230630103000.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc391667100>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 3032/5857
# Parsing GRIB: 3033/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230630100000.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230630100000.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc39167db80>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 3034/5857
# Parsing GRIB: 3035/5857
# Parsing GRIB: 3036/5857
# Parsing GRIB: 3037/5857
# Parsing GRIB: 3038/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230630084500.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230630084500.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc2e013f2e0>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Attempt 1/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230630084500.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230630084500.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc391548460>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 3039/5857
# Parsing GRIB: 3040/5857
# Parsing GRIB: 3041/5857
# Parsing GRIB: 3042/5857
# Parsing GRIB: 3043/5857
# Parsing GRIB: 3044/5857
# Parsing GRIB: 3045/5857
# Parsing GRIB: 3046/5857
# Parsing GRIB: 3047/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230630063000.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230630063000.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc391667520>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 3048/5857
# Parsing GRIB: 3049/5857
# Parsing GRIB: 3050/5857
# Parsing GRIB: 3051/5857
# Parsing GRIB: 3052/5857
# Parsing GRIB: 3053/5857
# Parsing GRIB: 3054/5857
# Parsing GRIB: 3055/5857
# Parsing GRIB: 3056/5857
# Parsing GRIB: 3057/5857
# Parsing GRIB: 3058/5857
# Parsing GRIB: 3059/5857
# Parsing GRIB: 3060/5857
# Parsing GRIB: 3061/5857
# Parsing GRIB: 3062/5857
# Parsing GRIB: 3063/5857
# Parsing GRIB: 3064/5857
# Parsing GRIB: 3065/5857
# Parsing GRIB: 3066/5857
# Parsing GRIB: 3067/5857
# Parsing GRIB: 3068/5857
# Parsing GRIB: 3069/5857
# Parsing GRIB: 3070/5857
# Parsing GRIB: 3071/5857
# Parsing GRIB: 3072/5857
# Parsing GRIB: 3073/5857
# Parsing GRIB: 3074/5857
# Parsing GRIB: 3075/5857
# Parsing GRIB: 3076/5857
# Parsing GRIB: 3077/5857
# Parsing GRIB: 3078/5857
# Parsing GRIB: 3079/5857
# Parsing GRIB: 3080/5857
# Parsing GRIB: 3081/5857
# Parsing GRIB: 3082/5857
# Parsing GRIB: 3083/5857
# Parsing GRIB: 3084/5857
# Parsing GRIB: 3085/5857
# Parsing GRIB: 3086/5857
# Parsing GRIB: 3087/5857
# Parsing GRIB: 3088/5857
# Parsing GRIB: 3089/5857
# Parsing GRIB: 3090/5857
# Parsing GRIB: 3091/5857
# Parsing GRIB: 3092/5857
# Parsing GRIB: 3093/5857
# Parsing GRIB: 3094/5857
# Parsing GRIB: 3095/5857
# Parsing GRIB: 3096/5857
# Parsing GRIB: 3097/5857
# Parsing GRIB: 3098/5857
# Parsing GRIB: 3099/5857
# Parsing GRIB: 3100/5857
# Parsing GRIB: 3101/5857
# Parsing GRIB: 3102/5857
# Parsing GRIB: 3103/5857
# Parsing GRIB: 3104/5857
# Parsing GRIB: 3105/5857
# Parsing GRIB: 3106/5857
# Parsing GRIB: 3107/5857
# Parsing GRIB: 3108/5857
# Parsing GRIB: 3109/5857
# Parsing GRIB: 3110/5857
# Parsing GRIB: 3111/5857
# Parsing GRIB: 3112/5857
# Parsing GRIB: 3113/5857
# Parsing GRIB: 3114/5857
# Parsing GRIB: 3115/5857
# Parsing GRIB: 3116/5857
# Parsing GRIB: 3117/5857
# Parsing GRIB: 3118/5857
# Parsing GRIB: 3119/5857
# Parsing GRIB: 3120/5857
# Parsing GRIB: 3121/5857
# Parsing GRIB: 3122/5857
# Parsing GRIB: 3123/5857
# Parsing GRIB: 3124/5857
# Parsing GRIB: 3125/5857
# Parsing GRIB: 3126/5857
# Parsing GRIB: 3127/5857
# Parsing GRIB: 3128/5857
# Parsing GRIB: 3129/5857
# Parsing GRIB: 3130/5857
# Parsing GRIB: 3131/5857
# Parsing GRIB: 3132/5857
# Parsing GRIB: 3133/5857
# Attempt 0/10: Could not download Product MSG3-SEVI-MSGCLMK-0100-0100-20230629090000.000000000Z-NA of Collection EO:EUM:DAT:MSG:CLM (due to a server-side error)
# Attempt 1/10: Could not download Product MSG3-SEVI-MSGCLMK-0100-0100-20230629090000.000000000Z-NA of Collection EO:EUM:DAT:MSG:CLM (due to a server-side error)
# Parsing GRIB: 3134/5857
# Parsing GRIB: 3135/5857
# Parsing GRIB: 3136/5857
# Parsing GRIB: 3137/5857
# Parsing GRIB: 3138/5857
# Parsing GRIB: 3139/5857
# Parsing GRIB: 3140/5857
# Parsing GRIB: 3141/5857
# Parsing GRIB: 3142/5857
# Parsing GRIB: 3143/5857
# Parsing GRIB: 3144/5857
# Parsing GRIB: 3145/5857
# Parsing GRIB: 3146/5857
# Parsing GRIB: 3147/5857
# Parsing GRIB: 3148/5857
# Parsing GRIB: 3149/5857
# Parsing GRIB: 3150/5857
# Parsing GRIB: 3151/5857
# Parsing GRIB: 3152/5857
# Parsing GRIB: 3153/5857
# Parsing GRIB: 3154/5857
# Parsing GRIB: 3155/5857
# Parsing GRIB: 3156/5857
# Parsing GRIB: 3157/5857
# Parsing GRIB: 3158/5857
# Parsing GRIB: 3159/5857
# Parsing GRIB: 3160/5857
# Parsing GRIB: 3161/5857
# Parsing GRIB: 3162/5857
# Parsing GRIB: 3163/5857
# Parsing GRIB: 3164/5857
# Parsing GRIB: 3165/5857
# Parsing GRIB: 3166/5857
# Parsing GRIB: 3167/5857
# Parsing GRIB: 3168/5857
# Parsing GRIB: 3169/5857
# Parsing GRIB: 3170/5857
# Parsing GRIB: 3171/5857
# Parsing GRIB: 3172/5857
# Parsing GRIB: 3173/5857
# Parsing GRIB: 3174/5857
# Parsing GRIB: 3175/5857
# Parsing GRIB: 3176/5857
# Parsing GRIB: 3177/5857
# Parsing GRIB: 3178/5857
# Parsing GRIB: 3179/5857
# Attempt 0/10: Could not download Product MSG3-SEVI-MSGCLMK-0100-0100-20230628213000.000000000Z-NA of Collection EO:EUM:DAT:MSG:CLM (due to a server-side error)
# Parsing GRIB: 3180/5857
# Parsing GRIB: 3181/5857
# Parsing GRIB: 3182/5857
# Parsing GRIB: 3183/5857
# Parsing GRIB: 3184/5857
# Parsing GRIB: 3185/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230628200000.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230628200000.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc39166cd30>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 3186/5857
# Parsing GRIB: 3187/5857
# Parsing GRIB: 3188/5857
# Parsing GRIB: 3189/5857
# Parsing GRIB: 3190/5857
# Parsing GRIB: 3191/5857
# Parsing GRIB: 3192/5857
# Parsing GRIB: 3193/5857
# Parsing GRIB: 3194/5857
# Parsing GRIB: 3195/5857
# Parsing GRIB: 3196/5857
# Parsing GRIB: 3197/5857
# Parsing GRIB: 3198/5857
# Parsing GRIB: 3199/5857
# Parsing GRIB: 3200/5857
# Parsing GRIB: 3201/5857
# Parsing GRIB: 3202/5857
# Parsing GRIB: 3203/5857
# Parsing GRIB: 3204/5857
# Parsing GRIB: 3205/5857
# Parsing GRIB: 3206/5857
# Parsing GRIB: 3207/5857
# Parsing GRIB: 3208/5857
# Parsing GRIB: 3209/5857
# Parsing GRIB: 3210/5857
# Parsing GRIB: 3211/5857
# Parsing GRIB: 3212/5857
# Parsing GRIB: 3213/5857
# Parsing GRIB: 3214/5857
# Parsing GRIB: 3215/5857
# Parsing GRIB: 3216/5857
# Parsing GRIB: 3217/5857
# Parsing GRIB: 3218/5857
# Parsing GRIB: 3219/5857
# Parsing GRIB: 3220/5857
# Parsing GRIB: 3221/5857
# Parsing GRIB: 3222/5857
# Attempt 0/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230628104500.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230628104500.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc391548d00>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Attempt 1/10: HTTPSConnectionPool(host='api.eumetsat.int', port=443): Max retries exceeded with url: /data/download/1.0.0/collections/EO%3AEUM%3ADAT%3AMSG%3ACLM/products/MSG3-SEVI-MSGCLMK-0100-0100-20230628104500.000000000Z-NA/entry?name=MSG3-SEVI-MSGCLMK-0100-0100-20230628104500.000000000Z-NA.grb (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc391667730>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Parsing GRIB: 3223/5857
# Parsing GRIB: 3224/5857
# Parsing GRIB: 3225/5857
# Parsing GRIB: 3226/5857
# Parsing GRIB: 3227/5857
# Parsing GRIB: 3228/5857
# Parsing GRIB: 3229/5857
# Parsing GRIB: 3230/5857
# Parsing GRIB: 3231/5857
# Parsing GRIB: 3232/5857
# Parsing GRIB: 3233/5857
# Parsing GRIB: 3234/5857
# Parsing GRIB: 3235/5857
# Parsing GRIB: 3236/5857
# Parsing GRIB: 3237/5857
# Parsing GRIB: 3238/5857
# Parsing GRIB: 3239/5857
# Parsing GRIB: 3240/5857
# Parsing GRIB: 3241/5857
# Parsing GRIB: 3242/5857
# Parsing GRIB: 3243/5857
# Parsing GRIB: 3244/5857
# Parsing GRIB: 3245/5857
# Parsing GRIB: 3246/5857
# Parsing GRIB: 3247/5857
# Parsing GRIB: 3248/5857
# Parsing GRIB: 3249/5857
# Parsing GRIB: 3250/5857
# Parsing GRIB: 3251/5857
# Parsing GRIB: 3252/5857
# Parsing GRIB: 3253/5857
# Parsing GRIB: 3254/5857
# Parsing GRIB: 3255/5857
# Parsing GRIB: 3256/5857
# Parsing GRIB: 3257/5857
# Attempt 0/10: Could not download Product MSG3-SEVI-MSGCLMK-0100-0100-20230628020000.000000000Z-NA of Collection EO:EUM:DAT:MSG:CLM (due to a server-side error)
# Attempt 1/10: Could not download Product MSG3-SEVI-MSGCLMK-0100-0100-20230628020000.000000000Z-NA of Collection EO:EUM:DAT:MSG:CLM (due to a server-side error)
# Parsing GRIB: 3258/5857

# %% [markdown]
# # Join monthly files into yearly and check for errors

# %%
# code to joining monthly data into yearly data file

import os
import pandas as pd

def join_csv_files(folder_path, output_file):
    all_dataframes = []
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            file_path = os.path.join(folder_path, filename)
            df = pd.read_csv(file_path)
            all_dataframes.append(df)

    if all_dataframes:
        # Reset the index for each dataframe before concatenating
        for idx, df in enumerate(all_dataframes):
            all_dataframes[idx] = df.reset_index(drop=True)

        combined_df = pd.concat(all_dataframes, ignore_index=True)
        combined_df.to_csv(output_file, index=False)
        print(f"Successfully joined {len(all_dataframes)} CSV files into {output_file}")
    else:
        print("No CSV files found in the specified folder.")

# Example usage:
folder_path = "/Users/eugenerotherham/Documents/AtherasAnalytics/clouds-outage-prediction-main/eumetsat_lab/stations/matm"
output_file = "/Users/eugenerotherham/Documents/AtherasAnalytics/clouds-outage-prediction-main/eumetsat_lab/stations/matm_cloud_2022-06_2023-08.txt"
join_csv_files(folder_path, output_file)
# Out:
# Successfully joined 5 CSV files into /Users/eugenerotherham/Documents/AtherasAnalytics/clouds-outage-prediction-main/eumetsat_lab/stations/matm_cloud_2022-06_2023-08.txt

# %%
# check time differences and format


'''
# check if there are any gaps in the data (time differences greater than 15 minutes)
cloud_df['time'] = pd.to_datetime(cloud_df['time'])
time_diff = cloud_df['time'].diff()


cloud_df['time_difference'] = time_diff
cloud_df['time_difference_exceeds_threshold'] = time_diff > pd.Timedelta(minutes=15)

if any(cloud_df['time_difference_exceeds_threshold']):
    print("Intervals greater than 15 minutes:")
    # print(cloud_df[cloud_df['time_difference_exceeds_threshold']])
    # Calculate the length of cloud_df where time differences exceed the threshold
    length_exceeding_threshold = len(cloud_df[cloud_df['time_difference_exceeds_threshold']])
    print(f"The length of cloud_df with time differences exceeding 15 minutes is: {length_exceeding_threshold}")
else:
    print("The dataset has complete and consistent time intervals (15 minutes apart).")

'''
